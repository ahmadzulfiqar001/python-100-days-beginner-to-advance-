# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadzulfiqar001/python-100-days-beginner-to-advance-/blob/main/DAY_6_of_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Indexing and Data Structure**

# %%
# Indexing

a = "Coca Cola"
a
# Out:
# 'Coca Cola'

# %%
a
# Out:
# 'Coca Cola'

# %%
a[0]
len(a)
# Out:
# 9

# %%
a[8]
# Out:
# 'a'

# %%
# last index is enclusive
a[0:9]
# Out:
# 'Coca Cola'

# %%
a[-4]
# Out:
# 'C'

# %%
a[-6:-1]
# Out:
# 'a Col'

# %%
food = "Biryani"
food
# Out:
# 'Biryani'

# %% [markdown]
# **Strings Method**

# %%
food
# Out:
# 'Biryani'

# %%
len(food)
# Out:
# 7

# %%
food.capitalize()
# Out:
# 'Biryani'

# %%
# upper case
food.upper()
# Out:
# 'BIRYANI'

# %%
# lower case
food.lower()
# Out:
# 'biryani'

# %%
name = "My name is Muhammad Ahamd"
name
# Out:
# 'My name is Muhammad Ahamd'

# %%
name.count("a")
# Out:
# 4

# %% [markdown]
# **Finding an index number in string**

# %%
name = "My name is ahmad"
name
# Out:
# 'My name is ahmad'

# %%
name.find("a")
# Out:
# 4

# %% [markdown]
# **How to split a string**

# %%
food = "i love samosa, pakora, karahai, and raita"
food
# Out:
# 'i love samosa, pakora, karahai, and raita'

# %%
food.split(",")
# Out:
# ['i love samosa', ' pakora', ' karahai', ' and raita']

# %% [markdown]
# **Basic Data Structure in Python**
#
# 01-TUPLE
#
# 02-DICTIONARIES
#
# 03-SET

# %%
## TUPLE

tup1= (4, 4.0, "Muhammad Ahmad", True)
tup1
# Out:
# (4, 4.0, 'Muhammad Ahmad', True)

# %%
type(tup1)
# Out:
# tuple

# %% [markdown]
# **Indexing in tuple**

# %%
tup1[2]
# Out:
# 'Muhammad Ahmad'

# %%
tup1[1]
# Out:
# 4.0

# %%
tup1[3]
# Out:
# True

# %%
#last element is exclusive

tup1[0:3]
# Out:
# (4, 4.0, 'Muhammad Ahmad')

# %%
# length of tuple

# %%
len(tup1)
# Out:
# 4

# %%
tup2 = (5, 5.5, "Awais", True)
tup2

tup1+tup2
# Out:
# (4, 4.0, 'Muhammad Ahmad', True, 5, 5.5, 'Awais', True)

# %%
tup1*2 + tup2
# Out:
# (4,
#  4.0,
#  'Muhammad Ahmad',
#  True,
#  4,
#  4.0,
#  'Muhammad Ahmad',
#  True,
#  5,
#  5.5,
#  'Awais',
#  True)

# %%
tup3 = (20,30,40,50,60)
tup3
# Out:
# (20, 30, 40, 50, 60)

# %%
min(tup3)

max(tup3)


tup3*2
# Out:
# (20, 30, 40, 50, 60, 20, 30, 40, 50, 60)

# %% [markdown]
# **List**

# %%
list1 =[2 , "ahmad, true"]
list1
# Out:
# [2, 'ahmad, true']

# %%
type(list1)
# Out:
# list

# %%
len(list1)
# Out:
# 2

# %%
list2 =[2, 3, "ahmad", 233, 457.8, False]
list2
# Out:
# [2, 3, 'ahmad', 233, 457.8, False]

# %%
list1 + list2
# Out:
# [2, 'ahmad, true', 2, 3, 'ahmad', 233, 457.8, False]

# %%
list1*2
# Out:
# [2, 'ahmad, true', 2, 'ahmad, true']

# %%
list1.reverse()
list1
# Out:
# ['ahmad, true', 2]

# %%
list1.append("Muhammad")
list1
# Out:
# ['ahmad, true', 2, 'Muhammad']

# %%
list1.count("ahmad")
list1
# Out:
# ['ahmad, true', 2, 'Muhammad']

# %%
list3 =[22,33,44,55,66,23,24,25,246,456,678]
list3
# Out:
# [22, 33, 44, 55, 66, 23, 24, 25, 246, 456, 678]

# %%
len(list3)
# Out:
# 11

# %%
list3.sort()
list3
# Out:
# [22, 23, 24, 25, 33, 44, 55, 66, 246, 456, 678]

# %%
list3*3
# Out:
# [22,
#  23,
#  24,
#  25,
#  33,
#  44,
#  55,
#  66,
#  246,
#  456,
#  678,
#  22,
#  23,
#  24,
#  25,
#  33,
#  44,
#  55,
#  66,
#  246,
#  456,
#  678,
#  22,
#  23,
#  24,
#  25,
#  33,
#  44,
#  55,
#  66,
#  246,
#  456,
#  678]

# %%
lists = list1 + list2
lists
# Out:
# ['ahmad, true', 2, 'Muhammad', 2, 3, 'ahmad', 233, 457.8, False]
