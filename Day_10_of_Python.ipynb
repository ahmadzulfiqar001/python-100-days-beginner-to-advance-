# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadzulfiqar001/python-100-days-beginner-to-advance-/blob/main/Day_10_of_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import_line

# %%
# import libraries

import seaborn as sns
import matplotlib.pyplot as plt

# load_dataset

phool = sns.load_dataset("iris")
phool

# draw a line plot

sns.barplot(x="species", y="sepal_width", data=phool)
plt.show()

# %%
# import libraries

import seaborn as sns
import matplotlib.pyplot as plt

# load_dataset

phool = sns.load_dataset("iris")
phool

# draw a line plot

sns.barplot(x="sepal_length", y="sepal_width", data=phool)
plt.show()

# %%
# import libraries

import seaborn as sns
import matplotlib.pyplot as plt

# load data_set

phool = sns.load_dataset("iris")
phool

# draw a plot
sns.barplot(x="species", y="petal_length", data=phool)
plt.show()

# %%
# import libraries

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# load dataset

kashti = sns.load_dataset("titanic")
kashti

#draw a plot

sns.barplot(x="class", y="fare", hue="sex", data=kashti, estimator= np.mean)
plt.show()

# %%
# import libraries

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# load_dataset

Kashti = sns.load_dataset("titanic")
Kashti

#draw a plot
sns.barplot(x="class", y="fare", hue="sex", data=kashti, estimator=np.mean, saturation=0.2)
plt.show()

# %%
# import libraries

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# load_dataset

Kashti = sns.load_dataset("titanic")
Kashti

#draw a plot
sns.barplot(x="class", y="fare", hue="sex", data=kashti, estimator=np.mean, saturation=1)
plt.show()

# %%
# import libraries

import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
kashti = sns.load_dataset("titanic")
kashti

#draw a line plot
sns.barplot(x="sex", y="alone", hue="who", data=kashti, order=["female", "male"], color="#7ffaa0", ci=None )
# Out:
# /tmp/ipykernel_23252/558097287.py:11: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="sex", y="alone", hue="who", data=kashti, order=["female", "male"], color="#7ffaa0", ci=None )
# /tmp/ipykernel_23252/558097287.py:11: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#7ffaa0'` for the same effect.
#
#   sns.barplot(x="sex", y="alone", hue="who", data=kashti, order=["female", "male"], color="#7ffaa0", ci=None )
# <Axes: xlabel='sex', ylabel='alone'>

# %%
# horizontal plot
# import libraries

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

#load dataset

kashti = sns.load_dataset("titanic")
kashti

#draw a plot
sns.barplot(x="fare", y="class", hue="sex", data=kashti, estimator=np.mean, saturation=1)
# Out:
# <Axes: xlabel='fare', ylabel='class'>

# %%
# import libraries

import seaborn as sns
import matplotlib.pyplot as plt
#load_Dataset
phool = sns.load_dataset("iris")
phool
# draw a line plot
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)
plt.title("Phool ka plot")
# set style
sns.set_style(style=None, rc=None)
sns.set_style("dark")
plt.show()

# %%
# importing required libarries

import seaborn as sns
import matplotlib.pyplot as plt

# read a titanic.csv file
# from seaborn library

kashti = sns.load_dataset("titanic")

sns.barplot(x="class", y="fare", data=kashti,
            linewidth=3, facecolor=(0.1,0.6,0.3,0.5),
            errcolor=".5",  edgecolor="0")
# Out:
# /tmp/ipykernel_23252/3674211823.py:11: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '.5'}` instead.
#
#   sns.barplot(x="class", y="fare", data=kashti,
# <Axes: xlabel='class', ylabel='fare'>

# %%
#import libraries
import seaborn
# canvas(baloon board)
seaborn.set(style='whitegrid')
# load dataset
kashti = seaborn.load_dataset("titanic")

seaborn.boxplot(x="class",
                y="fare",
                data = kashti)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
# import libraries

import seaborn

seaborn.set(style="whitegrid")

tip = seaborn.load_dataset("tips")
tip

seaborn.boxplot(x="day",y="tip", data= tip, saturation=1)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
# import libraries

import seaborn as sns
import pandas as pd
import numpy as np

tip = seaborn.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# import libraries

import seaborn as sns
# style of background of plot
sns.set(style="whitegrid")
#loading dataset
tip = sns.load_dataset("tips")

sns.boxplot(data=tip[['total_bill','size']])
# Out:
# <Axes: >

# %%
# import libraries

import seaborn as sns
# style of background of plot
sns.set(style="whitegrid")
#loading dataset
tip = sns.load_dataset("tips")

sns.boxplot(x="tip", y="day",hue="smoker",data=tip,
            palette="Set2", dodge=True )
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns

sns.set(style="whitegrid")
tip = sns.load_dataset("tips")
tip

sns.boxplot(x="tip", y="day", data=tip, color="#7ffaa0")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns

sns.set(style="whitegrid")
tip = sns.load_dataset("tips")
tip

sns.boxplot(x="tip", y="day", data=tip, hue="smoker")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns

sns.set(style="whitegrid")
tip = sns.load_dataset("tips")
tip

sns.boxplot( x='day',y='total_bill', hue='sex', data=tip, palette=['blue', 'pink'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import seaborn as sns

sns.set(style="whitegrid")
tip = sns.load_dataset("tips")
tip

sns.boxplot( x='day',y='total_bill', hue='sex', data=tip, palette={'Male': '#40dfff', 'Female': '#fffa73'})
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
