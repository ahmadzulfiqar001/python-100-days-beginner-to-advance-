# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadzulfiqar001/python-100-days-beginner-to-advance-/blob/main/Day_1_of_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# >
# **Print Function**

# %%
print("hello world")
# Out:
# hello world

# %%
print(1)
# Out:
# 1

# %%
print("India","Pakistan","Nepal","Sirilanka")
# Out:
# India Pakistan Nepal Sirilanka

# %% [markdown]
# print(4)

# %%
print("Pakistan",4,4.9)
# Out:
# Pakistan 4 4.9

# %%
print("India","Pakistan","Nepal","Sirilanka",sep='/')
# Out:
# India/Pakistan/Nepal/Sirilanka

# %%
print("India","Pakistan","Nepal","Sirilanka",sep='-')
# Out:
# India-Pakistan-Nepal-Sirilanka

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print("hello", end=' ')
print("world")
# Out:
# hello world

# %% [markdown]
# **Data Types**
# Basic types

# %%
#integar
print(4)
print(500000000000000000000000000555555555555555555555500000000000000)
print(1e308)
print(1e309)
# Out:
# 4
# 500000000000000000000000000555555555555555555555500000000000000
# 1e+308
# inf

# %%
#float
print(4.5)
print(1.7e308)
print(1.7e309)
# Out:
# 4.5
# 1.7e+308
# inf

# %%
#boolean
print("true")
print("false")
# Out:
# true
# false

# %%
#complex
print(4+5j)
# Out:
# (4+5j)

# %%
#string
print('hello')
print("hello")
print("""hello""")
# Out:
# hello
# hello
# hello

# %% [markdown]
# **Container data types**

# %%
#list
print([1,2,3,4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#tuple
print((1,2,3,4,5,6))
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary (searching is fast in dictionary)
print({"Name":"M.Ahamd","Age":30,"Gender":"Male"})
# Out:
# {'Name': 'M.Ahamd', 'Age': 30, 'Gender': 'Male'}

# %% [markdown]
# **Comments**
# it is the piece of code which is not executable

# %%
#comments

# %%
#this is a comment
