# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadzulfiqar001/python-100-days-beginner-to-advance-/blob/main/Day_3_of_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
fruit_basket = "Mangoes","oranges"
print(fruit_basket)
# Out:
# ('Mangoes', 'oranges')

# %%
fruit_basket = "Mangoes"
print(type(fruit_basket))
# Out:
# <class 'str'>

# %%
fruit_basket = 8
print(type(fruit_basket))
fruit_basket = 8
print(fruit_basket)
# Out:
# <class 'int'>
# 8

# %%
fruit_basket = "Mangoes","oranges"

del fruit_basket
print(fruit_basket)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_42139/1547096466.py in <cell line: 0>()
#       3 fruit_basket = 8
#       4 del fruit_basket
# ----> 5 print(fruit_basket)
#
# NameError: name 'fruit_basket' is not defined

# %% [markdown]
# **Input variables**

# %%
fruit_basket ="mangoes"
print(fruit_basket)
# Out:
# mangoes

# %%
fruit_basket=input("what is your fav fruit?")
print(fruit_basket)
# Out:
# what is your fav fruit?Mango
# Mango

# %%
name = input("what is your name?")
greeting = "hello!"

print(greeting,name)
# Out:
# what is your name?ahmad
# hello! ahmad

# %%
name = input("what is your name?")

print("Hello!",name)
# Out:
# what is your name?Ahmad
# Hello! Ahmad

# %%
name = input("what is your name? ")
age = input("how old are you? ")
greeting = "hello!"

print(greeting,name,", you are still young!")
# Out:
# what is your name? Ahmad
# how old are you? 18
# hello! Ahmad , you are still young!

# %% [markdown]
# **Conditional Logic**

# %%
# equal to ==
# less than
# greater than
# equal to
# not equal to
# less than equal to
# greater than equal to

# %%
print(4==4)
print(4!=4)
print(4>3)
print(3<6)
print(3<=5)
print(5>=4)
# Out:
# True
# False
# True
# True
# True
# True

# %%
#application of logical operators
hamad_age = 4
age_at_school = 5

print(hamad_age == age_at_school)
# Out:
# False

# %%
#input operators and logical
age_at_school = 5
hamad_age = input("how old the hamad is?")#input function
print(type(hamad_age))
print(hamad_age == age_at_school)#logical operator
# Out:
# how old the hamad is?5
# <class 'str'>
# False

# %%
#input operators and logical
age_at_school = 5
hamad_age = input("how old the hamad is?")#input function
hamad_age = int(hamad_age)
print(type(hamad_age))
print(hamad_age == age_at_school)#logical operator
# Out:
# how old the hamad is?5
# <class 'int'>
# True
