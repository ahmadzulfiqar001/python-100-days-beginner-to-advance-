# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadzulfiqar001/python-100-days-beginner-to-advance-/blob/main/Day_7_of_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dictionaries**
#
# -An un order collection of elements
#
# -key and value
#
# -Curly brases or brackects{}

# %%
# Food and thier prices
food1 = {"Samosa" : 30, "pakora" : 100, "Raita" : 20, "Salad" :50, "Chicken Roll" : 30}
food1
# Out:
# {'Samosa': 30, 'pakora': 100, 'Raita': 20, 'Salad': 50, 'Chicken Roll': 30}

# %%
type(food1)
# Out:
# dict

# %%
# extract data
keys1 = food1.keys()
keys1
# Out:
# dict_keys(['Samosa', 'pakora', 'Raita', 'Salad', 'Chicken Roll'])

# %%
value1 = food1.values()
value1
# Out:
# dict_values([30, 100, 20, 50, 30])

# %%
# adding new values
food1["tikki"] = 40
food1
# Out:
# {'Samosa': 30,
#  'pakora': 100,
#  'Raita': 20,
#  'Salad': 50,
#  'Chicken Roll': 30,
#  'tikki': 40,
#  'Tikki': 45}

# %%
# updating  values
food1["tikki"] = 45
food1
# Out:
# {'Samosa': 30,
#  'pakora': 100,
#  'Raita': 20,
#  'Salad': 50,
#  'Chicken Roll': 30,
#  'tikki': 45,
#  'Tikki': 45}

# %%
food2 = {"Dates": 50, "chocolates": 300, "sawaiya": 2000}
food2
# Out:
# {'Dates': 50, 'chocolates': 300, 'sawaiya': 2000}

# %%
#concatinate

food1.update(food2)
food1
# Out:
# {'Samosa': 30,
#  'pakora': 100,
#  'Raita': 20,
#  'Salad': 50,
#  'Chicken Roll': 30,
#  'tikki': 40,
#  'Tikki': 45,
#  'Dates': 50,
#  'chocolates': 300,
#  'sawaiya': 2000}

# %% [markdown]
# **Sets**
#
# -unorderd and unindexd
#
# -curly braces are used
#
# -No duplicates are allowed

# %%
s1 = {1, 2, 3, 4.5, 6.4, "Ahmad", "Sahiwal", "Codanics"}
s1
# Out:
# {1, 2, 3, 4.5, 6.4, 'Ahmad', 'Codanics', 'Sahiwal'}

# %%
s1.add( "Ahmad")
s1
# Out:
# {' Awais', 1, 2, 3, 4.5, 6.4, 'Ahmad', 'Awais', 'Codanics', 'Sahiwal'}

# %%
s1.remove(" Awais")
s1
# Out:
# {1, 2, 3, 4.5, 6.4, 'Ahmad', 'Codanics', 'Sahiwal'}

# %%
s2 = s1.copy()
s2
# Out:
# {1, 2, 3, 4.5, 6.4, 'Ahmad', 'Codanics', 'Sahiwal'}

# %%
s2 = s1
s2
# Out:
# {1, 2, 3, 4.5, 6.4, 'Ahmad', 'Codanics', 'Sahiwal'}

# %%
s3 = {1, 6.4, "Codanics", "Python"}
difference_set = s1.difference(s3)
difference_set
# Out:
# {2, 3, 4.5, 'Ahmad', 'Sahiwal'}

# %%
s4 = {1, 2, "Codanics"}
s1.difference_update(s4)
s1
# Out:
# {3, 4.5, 6.4, 'Ahmad', 'Sahiwal'}

# %%
s1
# Out:
# {3, 4.5, 6.4, 'Ahmad', 'Sahiwal'}

# %%
s1.discard(4.5)
s1
# Out:
# {3, 6.4, 'Ahmad', 'Sahiwal'}

# %%
s5 = {3, "Ahmad", "Codanics", 10}
intersection_set = s1.intersection(s5)
intersection_set
# Out:
# {3, 'Ahmad'}

# %%
s6 = {"Awais", 2, 3, 5.6, 78}
s1.intersection_update(s6)
s1
# Out:
# {3}

# %%
s1 = {1, 2, 3, 4.5, 6.4, "Ahmad", "Sahiwal", "Codanics"}
s1
# Out:
# {1, 2, 3, 4.5, 6.4, 'Ahmad', 'Codanics', 'Sahiwal'}

# %%
s1.isdisjoint(s6)
# Out:
# False

# %%
s1.issubset(s6)
# Out:
# False

# %%
s1.issuperset(s2)
# Out:
# True

# %%
s1.pop()
s1
# Out:
# {2, 3, 4.5, 6.4, 'Ahmad', 'Codanics', 'Sahiwal'}

# %%
s3 = s1.copy()
s3
# Out:
# {2, 3, 4.5, 6.4, 'Ahmad', 'Codanics', 'Sahiwal'}

# %%
s1.union(s6)
s1
# Out:
# {2, 3, 4.5, 6.4, 'Ahmad', 'Codanics', 'Sahiwal'}
