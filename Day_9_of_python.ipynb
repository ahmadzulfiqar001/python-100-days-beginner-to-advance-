# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadzulfiqar001/python-100-days-beginner-to-advance-/blob/main/Day_9_of_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# steps involved in data visuallization

# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# set a theme
sns.set_theme(style = "ticks", color_codes = True)

# import dataset (you can import your own data set also)
Kashti = sns.load_dataset("titanic")
print(Kashti)

# plot basic graph
p = sns.countplot(x="sex", data=Kashti)
plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# steps involved in data visuallization

# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# set a theme
sns.set_theme(style = "ticks", color_codes = True)

# import dataset (you can import your own data set also)
Kashti = sns.load_dataset("titanic")
#print(Kashti)

# # plot basic graph with in variable(count)
# p = sns.countplot(x="sex", data=Kashti)
# plt.show()

# plot basic graph with 2 variables (count plot) with  title
p =sns.countplot(x="sex", data=Kashti, hue="class")
p.set_title("Baba g ka count plot for Kashti")
plt.show()

# %%
# steps involved in data visuallization

# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# set a theme
sns.set_theme(style = "ticks", color_codes = True)

# import dataset (you can import your own data set also)
Kashti = sns.load_dataset("titanic")
print(Kashti)

# # plot basic graph with in variable(count)
p = sns.countplot(x="sex", data=Kashti)
plt.show()

# plot basic graph with 2 variables (count plot)
p =sns.countplot(x="sex", data=Kashti, hue="class")
plt.show()


# plot basic graph with 2 variables (count plot) with  title
p =sns.countplot(x="sex", data=Kashti, hue="class")
p.set_title("Baba g ka count plot for Kashti")
plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]
